# %%
##upload the dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd53274b-9257-4915-a402-a2bb135a71ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd53274b-9257-4915-a402-a2bb135a71ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# READ DATASETS

# %%
#load the dataset
import pandas as pd
df=pd.read_csv("archive.zip")
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# VISUALIZATION

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df=pd.DataFrame({'price':[2380000,1400000,1200000,838000,805000]})
df.head()
# Out:
#      price
# 0  2380000
# 1  1400000
# 2  1200000
# 3   838000
# 4   805000

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
df=pd.DataFrame({'No of bedrooms':[5,4,5,4,3],'No of bathrooms':[2.50,2.50,2.75,2.50,2.00]})
df.head()
# Out:
#    No of bedrooms  No of bathrooms
# 0               5             2.50
# 1               4             2.50
# 2               5             2.75
# 3               4             2.50
# 4               3             2.00

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
df=pd.DataFrame({'date':[42491,42491,42491,42491,42491],'No of floors':[2.0,1.5,1.5,2.0,1.5],'No of views':[4,0,0,0,0]})
df.head()
# Out:
#     date  No of floors  No of views
# 0  42491           2.0            4
# 1  42491           1.5            0
# 2  42491           1.5            0
# 3  42491           2.0            0
# 4  42491           1.5            0

# %% [markdown]
# DESCRIPTIVE STATISTICS(MEAN)

# %%
df=pd.DataFrame({'No of bedrooms':[5,4,5,4,3],'No of bathrooms':[2.50,2.50,2.75,2.50,2.00]})
df.head()
df.mean()
# Out:
# No of bedrooms     4.20
# No of bathrooms    2.45
# dtype: float64

# %% [markdown]
# MEDIAN

# %%
df=pd.DataFrame({'living area':[3650,2920,2910,3310,2710],'lot area':[9050,4000,9480,42998,4500],'No of floors':[2.0,1.5,1.5,2.0,1.5]})
df.head()
df.median(axis=0)
# Out:
# living area     2920.0
# lot area        9050.0
# No of floors       1.5
# dtype: float64

# %% [markdown]
# MODE

# %%
df=pd.DataFrame({'date':[42491,42491,42491,42491,42491]})
df.head()
df.mode()
# Out:
#     date
# 0  42491

# %% [markdown]
# VARIANCE

# %%
import numpy as np
lot_area=[9050,4000,9480,42998,4500]
print(np.var(lot_area))
# Out:
# 215213349.44000006

# %% [markdown]
# STANDARD DEVIATION

# %%
No_of_views=[4,0,0,0,0]
print(np.std(No_of_views))
# Out:
# 1.6000000000000003

# %% [markdown]
# MISSING VALUES

# %%
df=pd.DataFrame({'No of bedrooms':[5,4,5,4,3],'No of bathrooms':[2.50,2.50,2.75,2.50,2.00]})
df.head()
print(df.shape)
df.isna().sum()
df["No of bedrooms"].isnull()
# Out:
# (5, 2)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: No of bedrooms, dtype: bool
